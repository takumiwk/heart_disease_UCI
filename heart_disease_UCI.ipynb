# %% [markdown]
# # import

# %%
import pandas as pd

#pandasのデータフレーム表示時に何行まで表示するか
pd.set_option('display.max_columns', 100)

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import learning_curve
from sklearn.model_selection import validation_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
import matplotlib.ticker as ticker
from mpl_toolkits.mplot3d import Axes3D
from scipy import genfromtxt
from mpl_toolkits.mplot3d import Axes3D

#警告文の非表示
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # hert.csvをデータフレームに格納

# %%
df = pd.read_csv("heart.csv")

# %% [markdown]
# # 内容を確認
#
# 14属性
# 302のサンプルが確認できる。
#
# 内容：
# age = 年齢
# sex = 性別（1=男性,0=女性）
# cp = 胸痛タイプ
# trestbps = 安静時血圧
# chol = 血清コレストラル
# fbs　= FBS（1=真,0=偽）
# restecg = 安静時心電図結果
# thalach　= 最大心拍数
# exang　= 運動誘発狭心症（1=はい、0=いいえ）
# oldpeak = 安静時の運動によるST低下
# slope = ピーク運動STセグメントの勾配
# ca = 蛍光透視法で着色された主血管の数
# thal = 3 =正常 ６ ＝固定欠陥 7 =可逆性不良
#
# target = 結果

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# 7     44    1   1       120   263    0        1      173      0      0.0
# 8     52    1   2       172   199    1        1      162      0      0.5
# 9     57    1   2       150   168    0        1      174      0      1.6
# 10    54    1   0       140   239    0        1      160      0      1.2
# 11    48    0   2       130   275    0        1      139      0      0.2
# ...

# %% [markdown]
# 応答変数が２種類
# どちらも数がほとんど同じである。

# %%
df['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
df_exist=df[df["target"] == 1]
df_not_exist=df[df["target"] == 0]

# %%
print("df_exist")
print(df_exist['target'].value_counts())
print()
print("df_not_exist")
print(df_not_exist['target'].value_counts())
# Out:
# df_exist
# 1    165
# Name: target, dtype: int64
#
# df_not_exist
# 0    138
# Name: target, dtype: int64

# %%
#欠損値のない行は表示しない
print("df_exist")
print(df_exist.isnull().sum()[df_exist.isnull().sum()>0])
print()
print("df_not_exist")
print(df_not_exist.isnull().sum()[df_not_exist.isnull().sum()>0])
# Out:
# df_exist
# Series([], dtype: int64)
#
# df_not_exist
# Series([], dtype: int64)

# %% [markdown]
# 欠損地は存在しない
